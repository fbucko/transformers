# %%
import pandas as pd

# Read the parquet file
df = pd.read_parquet('../datasets/malware_2406_strict.parquet')

# Display the first few rows
print(df.head())

# Get summary information
print(df.info())
print(df.describe())
# Out:
#                        domain_name            label  dns_has_dnskey  \
# 0                 irradiateher.com  malware:unknown             0.0
# 1                   eloquentcs.com  malware:unknown             0.0
# 2  www.neutralsystemsolution.space  malware:unknown             0.0
# 3  www.drshiwanijainpainclinic.com  malware:unknown             0.0
# 4                      mkt9136.com  malware:unknown             0.0
#
#    dns_A_count  dns_AAAA_count  dns_MX_count  dns_NS_count  dns_TXT_count  \
# 0           10               0             0             4              0
# 1            1               0             2             2              2
# 2            1               0             0             0              0
# 3            1               0             0             0              0
# 4            1               0             2             4              1
#
#    dns_SOA_count  dns_CNAME_count  ...  rdap_ip_v4_count  rdap_ip_v6_count  \
# ...
